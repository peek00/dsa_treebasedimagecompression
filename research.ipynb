# %%
from PIL import Image

def count_pixel_colors(image_path):
    # Open the image
    image = Image.open(image_path)

    # Get the RGB values of all pixels
    pixels = list(image.getdata())

    # Create a dictionary to store pixel counts
    pixel_counts = {}

    # Count the pixels
    for pixel in pixels:
        if pixel in pixel_counts:
            pixel_counts[pixel] += 1
        else:
            pixel_counts[pixel] = 1

    # Sort the pixel counts by the number of pixels (in descending order)
    sorted_counts = sorted(pixel_counts.items(), key=lambda x: x[1], reverse=True)

    return sorted_counts

# %%
image_path = "D:/GitHub/CS201_Project/Original/1254659.png"  # Replace with the path to your image file
pixel_counts = count_pixel_colors(image_path)

for pixel, count in pixel_counts:
    print(f"Color: {pixel}, Count: {count}")
# Out:
# Color: (1, 1, 1), Count: 8010
# Color: (5, 5, 5), Count: 3380
# Color: (255, 255, 255), Count: 3001
# Color: (0, 0, 0), Count: 2984
# Color: (4, 4, 4), Count: 1428
# Color: (2, 2, 2), Count: 1239
# Color: (8, 8, 8), Count: 1044
# Color: (6, 6, 6), Count: 1023
# Color: (7, 7, 7), Count: 942
# Color: (3, 3, 3), Count: 897
# Color: (11, 11, 11), Count: 823
# Color: (0, 1, 0), Count: 700
# Color: (254, 254, 254), Count: 651
# Color: (9, 9, 9), Count: 583
# Color: (10, 10, 10), Count: 434
# Color: (14, 6, 3), Count: 421
# Color: (253, 253, 253), Count: 356
# Color: (12, 12, 12), Count: 352
# Color: (255, 254, 255), Count: 349
# Color: (17, 9, 6), Count: 337
# Color: (14, 14, 14), Count: 306
# Color: (13, 13, 13), Count: 295
# Color: (1, 0, 0), Count: 290
# Color: (5, 6, 0), Count: 272
# Color: (254, 255, 255), Count: 266
# Color: (16, 8, 5), Count: 259
# Color: (252, 252, 252), Count: 243
# Color: (255, 253, 255), Count: 234
# Color: (6, 0, 0), Count: 221
# ...

# %%
array = [[1,0,1], [1,0,1], [1,0,1], [1,0,1]] # 2 x2
max_width = 2
max_height = 2

for x in max_width:
    for y
